# %%
import os
import sys

os.chdir(r"C:\Users\LENOVO\Kidney-Disease-Classification-DL-Project-DVC")
sys.path.insert(0, os.path.join(os.getcwd(), "src"))

# %%
import importlib
common = importlib.import_module("cnnClassifier.utils.common")
if not hasattr(common, "save_json"):
	def _save_json(path, data):
		import json, os
		os.makedirs(os.path.dirname(path), exist_ok=True)
		with open(path, "w") as f:
			json.dump(data, f, indent=4)
	common.save_json = _save_json

from cnnClassifier.config.configuration import ConfigurationManager
from cnnClassifier.components.model_evaluation_mlflow import Evaluation

config = ConfigurationManager()
eval_config = config.get_evaluation_config()
evaluation = Evaluation(eval_config)
# Out:
# d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\mlflow\utils\requirements_utils.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-06-23 04:42:22,802: INFO: common: yaml file: C:\Users\LENOVO\Kidney-Disease-Classification-DL-Project-DVC\config\config.yaml loaded successfully]
# [2026-06-23 04:42:22,804: INFO: common: yaml file: C:\Users\LENOVO\Kidney-Disease-Classification-DL-Project-DVC\params.yaml loaded successfully]
# [2026-06-23 04:42:22,805: INFO: common: created directory at: artifacts]

# %%
evaluation.evaluation()
# Out:
# [2026-06-23 04:42:23,663: INFO: model_evaluation_mlflow: Loading model from: artifacts\training\trained_model.h5]
# [2026-06-23 04:42:23,664: INFO: model_evaluation_mlflow: Model file size: 59,551,336 bytes]
# [2026-06-23 04:42:23,946: INFO: model_evaluation_mlflow: Model weights loaded successfully!]
# [2026-06-23 04:42:23,955: INFO: model_evaluation_mlflow: Model loaded and compiled!]
# Found 210 images belonging to 2 classes.
# 14/14 [==============================] - 15s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000
# [2026-06-23 04:42:39,307: INFO: model_evaluation_mlflow: Loss: 0.0, Accuracy: 1.0]

# %%
evaluation.log_into_mlflow()
# Out:
# [2026-06-23 04:42:41,104: INFO: model_evaluation_mlflow: MLflow Tracking URI: https://dagshub.com/Anshika102005/Kidney-Disease-Classification-DL-Project-DVC.mlflow]
# [2026-06-23 04:42:42,259: INFO: model_evaluation_mlflow: Experiment set: Kidney-Disease-Classification]
# [2026-06-23 04:42:42,261: INFO: model_evaluation_mlflow: Starting MLflow run: kidney-experiment_2026-06-23_04-42-42]
# 2026/06/23 04:42:43 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# [2026-06-23 04:42:44,758: WARNING: save: Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 14). These functions will not be directly callable after loading.]
# [2026-06-23 04:42:45,293: INFO: builder_impl: Assets written to: C:\Users\LENOVO\AppData\Local\Temp\tmp8eq3139w\model\data\model\assets]
# 2026/06/23 04:42:55 WARNING mlflow.utils.requirements_utils: The following packages were not found in the public PyPI package index as of 2023-02-28; if these packages are not present in the public PyPI index, you must install them manually before loading your model: {'backports-tarfile'}
# d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# [2026-06-23 04:43:45,677: INFO: model_evaluation_mlflow: Run ID: d6576876b1ff4d6d8dec759cf7f00b7d]
# [2026-06-23 04:43:45,680: INFO: model_evaluation_mlflow: Run Name: kidney-experiment_2026-06-23_04-42-42]
# [2026-06-23 04:43:45,682: INFO: model_evaluation_mlflow: Experiment ID: 1]
# [2026-06-23 04:43:45,718: INFO: model_evaluation_mlflow: Scores saved to C:\Users\LENOVO\Kidney-Disease-Classification-DL-Project-DVC\scores.json]
# [2026-06-23 04:43:46,157: INFO: model_evaluation_mlflow: ✅ MLflow logging successful!]
