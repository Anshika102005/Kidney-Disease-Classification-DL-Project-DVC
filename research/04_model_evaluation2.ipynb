# %%
# Package is installed via: pip install -e .
# No manual path manipulation needed.

# %%
import os

# %%
os.chdir("../")

# %%
import importlib
import cnnClassifier.components.model_evaluation_mlflow as mod
importlib.reload(mod)
# Out:
# d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\mlflow\utils\requirements_utils.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# <module 'cnnClassifier.components.model_evaluation_mlflow' from 'D:\\Projects\\Kidney-Disease-Classification-DL-Project-DVC\\src\\cnnClassifier\\components\\model_evaluation_mlflow.py'>

# %%
from cnnClassifier.config.configuration import ConfigurationManager
from cnnClassifier.components.model_evaluation_mlflow import Evaluation

config = ConfigurationManager()
eval_config = config.get_evaluation_config()
evaluation = Evaluation(eval_config)
# Out:
# [2026-07-02 02:56:52,398: INFO: common: yaml file: D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\config\config.yaml loaded successfully]
# [2026-07-02 02:56:52,404: INFO: common: yaml file: D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\params.yaml loaded successfully]
# [2026-07-02 02:56:52,406: INFO: common: created directory at: D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\artifacts]

# %%
evaluation.log_into_mlflow()
# Out:
# [2026-07-02 02:56:54,756: INFO: model_evaluation_mlflow: Scores not found, running evaluation first...]
# [2026-07-02 02:56:54,757: INFO: model_evaluation_mlflow: Loading model from: D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\artifacts\training\trained_model.keras]
# [2026-07-02 02:56:55,198: INFO: model_evaluation_mlflow: Model loaded from .keras (Keras 2 compatible mode)]
# [2026-07-02 02:56:55,204: INFO: model_evaluation_mlflow: Model loaded and compiled!]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 evaluation.log_into_mlflow()
#
# File D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\src\cnnClassifier\components\model_evaluation_mlflow.py:274, in Evaluation.log_into_mlflow(self)
#     272 if not hasattr(self, "score"):
#     273     logger.info("Scores not found, running evaluation first...")
# --> 274     self.evaluation()
#     275 scores = {"loss": float(self.score[0]), "accuracy": float(self.score[1])}
#     276 scores_path = os.path.join(os.getcwd(), "scores.json")
#
# File D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\src\cnnClassifier\components\model_evaluation_mlflow.py:267, in Evaluation.evaluation(self)
#     261 self.model.compile(
#     262     optimizer="adam",
#     263     loss="categorical_crossentropy",
#     264     metrics=["accuracy"]
#     265 )
#     266 logger.info("Model loaded and compiled!")
# --> 267 self._valid_generator()
#     268 self.score = self.model.evaluate(self.valid_generator)
#     269 logger.info(f"Loss: {self.score[0]}, Accuracy: {self.score[1]}")
#
# File D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\src\cnnClassifier\components\model_evaluation_mlflow.py:27, in Evaluation._valid_generator(self)
#      19 dataflow_kwargs = dict(
#      20     target_size=self.config.params_image_size[:-1],
#      21     batch_size=self.config.params_batch_size,
#      22     interpolation="bilinear"
#      23 )
#      24 valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
#      25     preprocessing_function=preprocess_input
#      26 )
# ---> 27 self.valid_generator = valid_datagenerator.flow_from_directory(
#      28     directory=self.config.test_data,
#      29     shuffle=False,
#      30     **dataflow_kwargs
#      31 )
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\preprocessing\image.py:1648, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1562 def flow_from_directory(
#    1563     self,
#    1564     directory,
#    (...)
#    1578     keep_aspect_ratio=False,
#    1579 ):
#    1580     """Takes the path to a directory & generates batches of augmented data.
#    1581
#    1582     Args:
#    (...)
#    1646             and `y` is a numpy array of corresponding labels.
#    1647     """
# -> 1648     return DirectoryIterator(
#    1649         directory,
#    1650         self,
#    1651         target_size=target_size,
#    1652         color_mode=color_mode,
#    1653         keep_aspect_ratio=keep_aspect_ratio,
#    1654         classes=classes,
#    1655         class_mode=class_mode,
#    1656         data_format=self.data_format,
#    1657         batch_size=batch_size,
#    1658         shuffle=shuffle,
#    1659         seed=seed,
#    1660         save_to_dir=save_to_dir,
#    1661         save_prefix=save_prefix,
#    1662         save_format=save_format,
#    1663         follow_links=follow_links,
#    1664         subset=subset,
#    1665         interpolation=interpolation,
#    1666         dtype=self.dtype,
#    1667     )
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\preprocessing\image.py:563, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     561 if not classes:
#     562     classes = []
# --> 563     for subdir in sorted(os.listdir(directory)):
#     564         if os.path.isdir(os.path.join(directory, subdir)):
#     565             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\Projects\\Kidney-Disease-Classification-DL-Project-DVC\\artifacts\\data_ingestion\\classification_data\\test'
