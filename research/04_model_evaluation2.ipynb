# %%
# Package is installed via: pip install -e .
# No manual path manipulation needed.

# %%
import os

# %%
os.chdir("../")

# %%
import importlib
import cnnClassifier.components.model_evaluation_mlflow as mod
importlib.reload(mod)
# Out:
# d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\mlflow\utils\requirements_utils.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# <module 'cnnClassifier.components.model_evaluation_mlflow' from 'D:\\Projects\\Kidney-Disease-Classification-DL-Project-DVC\\src\\cnnClassifier\\components\\model_evaluation_mlflow.py'>

# %%
from cnnClassifier.config.configuration import ConfigurationManager
from cnnClassifier.components.model_evaluation_mlflow import Evaluation

config = ConfigurationManager()
eval_config = config.get_evaluation_config()
evaluation = Evaluation(eval_config)
# Out:
# [2026-07-01 02:07:25,291: INFO: common: yaml file: D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\config\config.yaml loaded successfully]
# [2026-07-01 02:07:25,295: INFO: common: yaml file: D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\params.yaml loaded successfully]
# [2026-07-01 02:07:25,296: INFO: common: created directory at: D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\artifacts]

# %%
evaluation.log_into_mlflow()
# Out:
# [2026-07-01 02:08:20,274: INFO: model_evaluation_mlflow: Scores not found, running evaluation first...]
# [2026-07-01 02:08:20,275: INFO: model_evaluation_mlflow: Loading model from: D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\artifacts\training\trained_model.keras]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\engine\base_layer.py:868, in Layer.from_config(cls, config)
#     867 try:
# --> 868     return cls(**config)
#     869 except Exception as e:
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\dtensor\utils.py:96, in allow_initializer_layout.<locals>._wrap_function(layer_instance, *args, **kwargs)
#      94             layout_args[variable_name + "_layout"] = layout
# ---> 96 init_method(layer_instance, *args, **kwargs)
#      98 # Inject the layout parameter after the invocation of __init__()
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\layers\convolutional\conv2d.py:179, in Conv2D.__init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     158 @utils.allow_initializer_layout
#     159 def __init__(
#     160     self,
#    (...)
#     177     **kwargs
#     178 ):
# --> 179     super().__init__(
#     180         rank=2,
#     181         filters=filters,
#     182         kernel_size=kernel_size,
#     183         strides=strides,
#     184         padding=padding,
#     185         data_format=data_format,
#     186         dilation_rate=dilation_rate,
#     187         groups=groups,
#     188         activation=activations.get(activation),
#     189         use_bias=use_bias,
#     190         kernel_initializer=initializers.get(kernel_initializer),
#     191         bias_initializer=initializers.get(bias_initializer),
#     192         kernel_regularizer=regularizers.get(kernel_regularizer),
#     193         bias_regularizer=regularizers.get(bias_regularizer),
#     194         activity_regularizer=regularizers.get(activity_regularizer),
#     195         kernel_constraint=constraints.get(kernel_constraint),
#     196         bias_constraint=constraints.get(bias_constraint),
#     197         **kwargs
#     198     )
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\layers\convolutional\base_conv.py:118, in Conv.__init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, trainable, name, conv_op, **kwargs)
#      94 def __init__(
#      95     self,
#      96     rank,
#    (...)
#     116     **kwargs,
#     117 ):
# --> 118     super().__init__(
#     119         trainable=trainable,
#     120         name=name,
#     121         activity_regularizer=regularizers.get(activity_regularizer),
#     122         **kwargs,
#     123     )
#     124     self.rank = rank
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\engine\base_layer.py:408, in Layer.__init__(self, trainable, name, dtype, dynamic, **kwargs)
#     403 # Note that models also have a dtype policy, as they are layers. For
#     404 # functional models, the policy is only used in Model.compile, which
#     405 # wraps the optimizer with a LossScaleOptimizer if the policy name is
#     406 # "mixed_float16". Subclassed models additionally use the policy's
#     407 # compute and variable dtypes, as like any ordinary layer.
# --> 408 self._set_dtype_policy(dtype)
#     409 # Boolean indicating whether the layer automatically casts its inputs to
#     410 # the layer's compute_dtype.
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\engine\base_layer.py:2680, in Layer._set_dtype_policy(self, dtype)
#    2679 elif isinstance(dtype, dict):
# -> 2680     self._dtype_policy = policy.deserialize(dtype)
#    2681 elif isinstance(dtype, str) and dtype in (
#    2682     "mixed_float16",
#    2683     "mixed_bfloat16",
#    2684 ):
#    2685     # The isinstance check is required since np.dtype raises an error if
#    2686     # compared to a non-dtype string.
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\mixed_precision\policy.py:515, in deserialize(config, custom_objects)
#     514 module_objects = {"Policy": Policy, "PolicyV1": Policy}
# --> 515 return serialization.deserialize_keras_object(
#     516     config,
#     517     module_objects=module_objects,
#     518     custom_objects=custom_objects,
#     519     printable_module_name="dtype policy",
#     520 )
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\saving\legacy\serialization.py:486, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     485 config = identifier
# --> 486 (cls, cls_config) = class_and_config_for_serialized_keras_object(
#     487     config, module_objects, custom_objects, printable_module_name
#     488 )
#     490 # If this object has already been loaded (i.e. it's shared between
#     491 # multiple objects), return the already-loaded object.
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\saving\legacy\serialization.py:368, in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     367 if cls is None:
# --> 368     raise ValueError(
#     369         f"Unknown {printable_module_name}: '{class_name}'. "
#     370         "Please ensure you are using a `keras.utils.custom_object_scope` "
#     371         "and that this object is included in the scope. See "
#     372         "https://www.tensorflow.org/guide/keras/save_and_serialize"
#     373         "#registering_the_custom_object for details."
#     374     )
#     376 cls_config = config["config"]
#
# ValueError: Unknown dtype policy: 'DTypePolicy'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 evaluation.log_into_mlflow()
#
# File D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\src\cnnClassifier\components\model_evaluation_mlflow.py:76, in Evaluation.log_into_mlflow(self)
#      74 if not hasattr(self, "score"):
#      75     logger.info("Scores not found, running evaluation first...")
# ---> 76     self.evaluation()
#      77 scores = {"loss": float(self.score[0]), "accuracy": float(self.score[1])}
#      78 scores_path = os.path.join(os.getcwd(), "scores.json")
#
# File D:\Projects\Kidney-Disease-Classification-DL-Project-DVC\src\cnnClassifier\components\model_evaluation_mlflow.py:55, in Evaluation.evaluation(self)
#      53 orig = self._patch_input_layer()
#      54 try:
# ---> 55     self.model = tf.keras.models.load_model(
#      56         path,
#      57         compile=False,
#      58         custom_objects={"Functional": tf.keras.Model}
#      59     )
#      60 finally:
#      61     self._restore_input_layer(orig)
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\saving\saving_api.py:204, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     199     if kwargs:
#     200         raise ValueError(
#     201             "The following argument(s) are not supported "
#     202             f"with the native Keras format: {list(kwargs.keys())}"
#     203         )
# --> 204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
#     208         safe_mode=safe_mode,
#     209     )
#     211 # Legacy case.
#     212 return legacy_sm_saving_lib.load_model(
#     213     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214 )
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\saving\saving_lib.py:277, in load_model(filepath, custom_objects, compile, safe_mode)
#     274             asset_store.close()
#     276 except Exception as e:
# --> 277     raise e
#     278 else:
#     279     return model
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\saving\saving_lib.py:242, in load_model(filepath, custom_objects, compile, safe_mode)
#     240 # Construct the model from the configuration file in the archive.
#     241 with ObjectSharingScope():
# --> 242     model = deserialize_keras_object(
#     243         config_dict, custom_objects, safe_mode=safe_mode
#     244     )
#     246 all_filenames = zf.namelist()
#     247 if _VARS_FNAME + ".h5" in all_filenames:
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\saving\serialization_lib.py:502, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     500 safe_mode_scope = SafeModeScope(safe_mode)
#     501 with custom_obj_scope, safe_mode_scope:
# --> 502     instance = cls.from_config(inner_config)
#     503     build_config = config.get("build_config", None)
#     504     if build_config:
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\engine\training.py:3053, in Model.from_config(cls, config, custom_objects)
#    3045 revivable_as_functional = (
#    3046     cls in {functional.Functional, Model}
#    3047     or argspec.args[1:] == functional_init_args
#    3048     or (argspec.varargs == "args" and argspec.varkw == "kwargs")
#    3049 )
#    3050 if is_functional_config and revivable_as_functional:
#    3051     # Revive Functional model
#    3052     # (but not Functional subclasses with a custom __init__)
# -> 3053     inputs, outputs, layers = functional.reconstruct_from_config(
#    3054         config, custom_objects
#    3055     )
#    3056     model = cls(
#    3057         inputs=inputs, outputs=outputs, name=config.get("name")
#    3058     )
#    3059     functional.connect_ancillary_layers(model, layers)
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\engine\functional.py:1483, in reconstruct_from_config(config, custom_objects, created_layers)
#    1481 # First, we create all layers and enqueue nodes to be processed
#    1482 for layer_data in config["layers"]:
# -> 1483     process_layer(layer_data)
#    1484 # Then we process nodes in order of layer depth.
#    1485 # Nodes that cannot yet be processed (if the inbound node
#    1486 # does not yet exist) are re-enqueued, and the process
#    1487 # is repeated until all nodes are processed.
#    1488 while unprocessed_nodes:
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\engine\functional.py:1464, in reconstruct_from_config.<locals>.process_layer(layer_data)
#    1460 else:
#    1461     # Instantiate layer.
#    1462     from keras.layers import deserialize as deserialize_layer
# -> 1464     layer = deserialize_layer(layer_data, custom_objects=custom_objects)
#    1465     created_layers[layer_name] = layer
#    1467 node_count_by_layer[layer] = int(_should_skip_first_node(layer))
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\layers\serialization.py:265, in deserialize(config, custom_objects, use_legacy_format)
#     257     return legacy_serialization.deserialize_keras_object(
#     258         config,
#     259         module_objects=LOCAL.ALL_OBJECTS,
#     260         custom_objects=custom_objects,
#     261         printable_module_name="layer",
#     262     )
#     264 # To be replaced by new serialization_lib
# --> 265 return legacy_serialization.deserialize_keras_object(
#     266     config,
#     267     module_objects=LOCAL.ALL_OBJECTS,
#     268     custom_objects=custom_objects,
#     269     printable_module_name="layer",
#     270 )
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\saving\legacy\serialization.py:513, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     511     else:
#     512         with object_registration.CustomObjectScope(custom_objects):
# --> 513             deserialized_obj = cls.from_config(cls_config)
#     514 else:
#     515     # Then `cls` may be a function returning a class.
#     516     # in this case by convention `config` holds
#     517     # the kwargs of the function.
#     518     custom_objects = custom_objects or {}
#
# File d:\Software\Anaconda\envs\kidney-disease\lib\site-packages\keras\engine\base_layer.py:870, in Layer.from_config(cls, config)
#     868     return cls(**config)
#     869 except Exception as e:
# --> 870     raise TypeError(
#     871         f"Error when deserializing class '{cls.__name__}' using "
#     872         f"config={config}.\n\nException encountered: {e}"
#     873     )
#
# TypeError: Error when deserializing class 'Conv2D' using config={'name': 'block1_conv1', 'trainable': False, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 64, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}.
#
# Exception encountered: Unknown dtype policy: 'DTypePolicy'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.
