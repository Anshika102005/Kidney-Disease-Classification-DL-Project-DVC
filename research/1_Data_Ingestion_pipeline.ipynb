# %%
from pathlib import Path
import os
import sys

# Add the repository local src folder to sys.path before imports.
repo_root = Path.cwd()
for candidate in [repo_root, *repo_root.parents]:
    if (candidate / "src" / "cnnClassifier").exists():
        repo_root = candidate
        break
else:
    raise FileNotFoundError("Could not find repository root containing src/cnnClassifier")

sys.path.insert(0, str(repo_root / "src"))

# Ensure notebook uses the current workspace package, not a previously cached installation.
for module_name in list(sys.modules):
    if module_name.startswith("cnnClassifier"):
        del sys.modules[module_name]

from cnnClassifier.pipeline.stage_01_data_ingestion import DataIngestionTrainingPipeline

pipeline = DataIngestionTrainingPipeline()
try:
    pipeline.main()
except FileNotFoundError as e:
    print(f"Error: {e}")
    print("Please ensure:")
    print("1. The CT-KIDNEY-DATASET exists at the expected location, OR")
    print("2. Update the source_URL in config.yaml to point to the dataset location")
# Out:
# [2026-07-05 22:08:26,134: INFO: common: yaml file: /mnt/d/Projects/Kidney-Disease-Classification-DL-Project-DVC/config/config.yaml loaded successfully]
# [2026-07-05 22:08:26,155: INFO: common: yaml file: /mnt/d/Projects/Kidney-Disease-Classification-DL-Project-DVC/params.yaml loaded successfully]
# [2026-07-05 22:08:26,168: INFO: common: created directory at: /mnt/d/Projects/Kidney-Disease-Classification-DL-Project-DVC/artifacts]
# [2026-07-05 22:08:26,180: INFO: common: created directory at: /mnt/d/Projects/Kidney-Disease-Classification-DL-Project-DVC/artifacts/data_ingestion]
# [2026-07-05 22:08:26,201: INFO: data_ingestion: Using local dataset: /mnt/d/Projects/Kidney-Disease-Classification-DL-Project-DVC/artifacts/Data Ingestion/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone]
# [2026-07-05 22:08:26,483: INFO: data_ingestion: Organized dataset already exists at: /mnt/d/Projects/Kidney-Disease-Classification-DL-Project-DVC/artifacts/data_ingestion. Skipping copy.]
# [2026-07-05 22:08:26,583: INFO: data_ingestion: Classification data (train): {'Cyst': 3614, 'Normal': 4972, 'Stone': 1344, 'Tumor': 2224}]
# [2026-07-05 22:08:26,647: INFO: data_ingestion: Classification data (test): {'Cyst': 1017, 'Normal': 1417, 'Stone': 379, 'Tumor': 625}]
# [2026-07-05 22:08:26,649: INFO: data_ingestion: Dataset organization completed successfully!]
