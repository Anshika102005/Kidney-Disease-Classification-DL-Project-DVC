# %%
from pathlib import Path
import os
import sys

# Add the repository local src folder to sys.path before imports.
repo_root = Path.cwd()
for candidate in [repo_root, *repo_root.parents]:
    if (candidate / "src" / "cnnClassifier").exists():
        repo_root = candidate
        break
else:
    raise FileNotFoundError("Could not find repository root containing src/cnnClassifier")

sys.path.insert(0, str(repo_root / "src"))

# Ensure notebook uses the current workspace package, not a previously cached installation.
for module_name in list(sys.modules):
    if module_name.startswith("cnnClassifier"):
        del sys.modules[module_name]

from cnnClassifier.pipeline.stage_01_data_ingestion import DataIngestionTrainingPipeline

pipeline = DataIngestionTrainingPipeline()
pipeline.main()
# Out:
# [2026-06-11 04:20:04,959: INFO: common: yaml file: C:\Users\LENOVO\Kidney-Disease-Classification-DL-Project-DVC\config\config.yaml loaded successfully]
# [2026-06-11 04:20:04,962: INFO: common: yaml file: C:\Users\LENOVO\Kidney-Disease-Classification-DL-Project-DVC\params.yaml loaded successfully]
# [2026-06-11 04:20:04,964: INFO: common: created directory at: artifacts]
# [2026-06-11 04:20:04,965: INFO: common: created directory at: artifacts/data_ingestion]
# [2026-06-11 04:20:04,967: INFO: data_ingestion: Copying data from C:\Users\LENOVO\Kidney-Disease-Classification-DL-Project-DVC\kidney.zip to artifacts\data_ingestion\data.zip]
# [2026-06-11 04:20:04,968: INFO: data_ingestion: File already exists at: artifacts\data_ingestion\data.zip]
# [2026-06-11 04:20:04,970: INFO: data_ingestion: Extracting artifacts\data_ingestion\data.zip to artifacts\data_ingestion]
# [2026-06-11 04:20:06,620: INFO: data_ingestion: Extraction completed successfully!]
